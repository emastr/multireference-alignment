# %%
import jax
from jax import grad, vmap, jit
import jax.numpy as jnp
import matplotlib.pyplot as plt


f = lambda t: jnp.sin(2*jnp.pi*t)
df = vmap(grad(f))

t = jnp.linspace(0,1,200)

plt.plot(t, f(t))
plt.plot(t, df(t))
