# %%
import jax
from jax.numpy.fft import fft, ifft
import jax.numpy as jnp
import matplotlib.pyplot as plt  
from jax import grad, vmap


import sys
root = '/home/emastr/github/phd/projects/vahid_project/'
sys.path.append('..')
sys.path.append(f'{root}src/')
sys.path.append(f'{root}util/')
sys.path.append(f'{root}data/')
from multiprocessing import Pool
from matplotlib.colors import LogNorm
from alignment_vmap import *
from alignment_vmap import em_method, fix_point_iter, align_average, autocorr_fft, hessian_declarative, hessian_declarative_real
from alignment_vmap import align_average_and_project, align, invariants_from_data, bispectrum_inversion

def get_samples(key, x, noise_std, N):
    L = len(x)
    shiftkey, noisekey = jax.random.split(key, 2)
    shift = jax.random.randint(shiftkey, (N,), 0, L)
    noise = jax.random.normal(noisekey, (N, L)) * noise_std
    y = vmap(lambda s, z: jnp.roll(x + z, s), in_axes=(0, 0))(shift, noise)
    return y, noise, shift

# Use finite difference hessian for stepping.

# %%
outer = lambda x, y: jnp.einsum('i,j->ij', x.conj(), y)
inner = lambda x, y: jnp.einsum('i,i->', x.conj(), y)
diff = lambda x: (x - jnp.roll(x, len(x)//10))/float(len(x)//10)*float(len(x))

Lhalf = 3
L = 2*Lhalf + 1
t = jnp.linspace(0, 2*jnp.pi, L+1)[:-1]
#f = lambda t: t == 0. #> jnp.pi
f = lambda t: t> jnp.pi
stdev = 1.0
N = 50000
x = f(t)
y, noise, shift = get_samples(random.PRNGKey(4), x, stdev, N)

xfft = fft(x)
xfft_abs = jnp.abs(xfft)
xfft0 = xfft[0]
yfft = fft(y, axis=1)    
ymean, yauto_fft, _ = invariants_from_data(y, stdev)
    
    
def to_xfft(angles, xfft_abs, xfft0):
    angles = jnp.concatenate([angles, -angles[::-1]])
    xfft = jnp.concatenate([jnp.array([xfft0]), jnp.exp(1j * angles) * xfft_abs[1:]])
    return xfft 

def shift_fft(shift, xfft):
    angles = jnp.angle(xfft[1:Lhalf+1])
    xfft = to_xfft(angles+shift, jnp.abs(xfft), xfft[0])
    return xfft
    
def loss(xfft):
    return loss_fft(xfft, yfft)

def maxcorr(zfft, noise):
    z = ifft(zfft).real
    
    z = z - align(zfft, xfft, x)
    zfft = fft(z)
    
    alignn = lambda n: align(zfft, fft(n), n)
    maxcorr = lambda n: jnp.dot(z, alignn(n))
    return jnp.mean(vmap(maxcorr)(noise))
    
def conv(zfft, noise):
    z = ifft(zfft).real
    loss_z = lambda n: loss_fft(xfft, jnp.array([fft(z + n)]))
    return jnp.mean(vmap(loss_z)(noise))


def loss_angle(angle, xfft_abs, xfft0):
    xfft = to_xfft(angle, xfft_abs, xfft0)
    return loss(xfft)

def dist_angle(angle, xfft_abs, xfft0):
    xfft0 = to_xfft(angle, xfft_abs, xfft0)
    return loss_fft(xfft0, jnp.array([xfft]))

def einstein_bias(angle, xfft_abs, xfft0):
    xfft0 = to_xfft(angle, xfft_abs, xfft0)
    return maxcorr(xfft0, noise)

def conv_loss(angle, xfft_abs, xfft0):
    xfft0 = to_xfft(angle, xfft_abs, xfft0)
    return conv(xfft0, noise)

def e(i):
    e = jnp.zeros(Lhalf)
    e = e.at[i].set(1.)
    return e

def en(i, n):
    e = jnp.zeros(n)
    e = e.at[i].set(1.)
    return e

def loss_wrap_vmap(loss_wrap, t1, t2, i1, i2):
    U = jnp.zeros((M, M))
    for i in range(M):
        U = U.at[i, :].set(vmap(lambda t1, t2: loss_wrap(t1, t2, i1, i2))(t1[i,:], t2[i,:]))
        print(i, end="\r")
    return U  

def get_slices(loss_wrap, T1, T2):
    U1 = loss_wrap_vmap(loss_wrap, T1, T2, 0, 1)
    U2 = loss_wrap_vmap(loss_wrap, T1, T2, 0, 2)
    U3 = loss_wrap_vmap(loss_wrap, T1, T2, 1, 2)
    return U1, U2, U3
        
M = 100
angles = jnp.angle(xfft[1:Lhalf+1])
angles = angles + jnp.pi * jnp.array([1., 0., 0.])
i, j = 0, 1

loss_wrap = lambda t1, t2, i1, i2: loss_angle(angles + t1 * en(i1, len(angles)) + t2 * en(i2, len(angles)), xfft_abs, xfft0)
dist_wrap = lambda t1, t2, i1, i2: dist_angle(angles + t1 * en(i1, len(angles)) + t2 * en(i2, len(angles)), xfft_abs, xfft0)
bias_wrap = lambda t1, t2, i1, i2: einstein_bias(angles + t1 * en(i1, len(angles)) + t2 * en(i2, len(angles)), xfft_abs, xfft0)
conv_wrap = lambda t1, t2, i1, i2: conv_loss(angles + t1 * en(i1, len(angles)) + t2 * en(i2, len(angles)), xfft_abs, xfft0)

t1 = jnp.linspace(-jnp.pi, jnp.pi, M)
t2 = jnp.linspace(-jnp.pi, jnp.pi, M)
T1, T2 = jnp.meshgrid(t1, t2)


U1, U2, U3 = get_slices(loss_wrap, T1, T2)
D1, D2, D3 = get_slices(dist_wrap, T1, T2)
B1, B2, B3 = get_slices(bias_wrap, T1, T2)
C1, C2, C3 = get_slices(conv_wrap, T1, T2)
# Out:
# 99

# %%
def stack_periodic(U):
    U = jnp.concatenate([U, U], axis=0)
    U = jnp.concatenate([U, U], axis=1)
    return U

def stack_shift(T1, T2, i1, i2):
    T1 = jnp.concatenate([T1, T1+2*jnp.pi], axis=1)
    T1 = jnp.concatenate([T1, T1], axis=0)
    
    T2 = jnp.concatenate([T2, T2+2*jnp.pi], axis=0)
    T2 = jnp.concatenate([T2, T2], axis=1)
    return T1 + angles[i1], T2 + angles[i2]

xyz = (angles[0], angles[1], angles[2])

def plot(T1, T2, U1, U2, U3):
    plt.figure(figsize=(15, 5))
    plt.subplot(131)
    plt.title(f"$\\theta_2={angles[2]/jnp.pi:.2f}\\pi$")
    plt.pcolormesh(*stack_shift(T1,T2, 0, 1), stack_periodic(U1)) 
    plt.xticks([i*jnp.pi for i in range(5)], [f"${i}\pi$" for i in range(5)]) 
    plt.yticks([i*jnp.pi for i in range(5)], [f"${i}\pi$" for i in range(5)]) 
    plt.grid()
    plt.xlabel("$\\theta_0$")
    plt.ylabel("$\\theta_1$")
    plt.scatter(xyz[0], xyz[1], c="red", zorder=10)

    plt.subplot(132)
    plt.title(f"$\\theta_1={angles[1]/jnp.pi:.2f}\\pi$")
    plt.pcolormesh(*stack_shift(T1,T2, 0, 2), stack_periodic(U2)) 
    plt.xlabel("$\\theta_0$")
    plt.ylabel("$\\theta_2$")
    plt.xticks([i*jnp.pi for i in range(5)], [f"${i}\pi$" for i in range(5)]) 
    plt.yticks([i*jnp.pi for i in range(5)], [f"${i}\pi$" for i in range(5)]) 
    plt.scatter(xyz[0], xyz[2], c="red", zorder=10)
    plt.grid()

    plt.subplot(133)
    plt.title(f"$\\theta_0={angles[0]/jnp.pi:.2f}\\pi$")
    plt.pcolormesh(*stack_shift(T1,T2, 1, 2), stack_periodic(U3)) 
    plt.xlabel("$\\theta_1$")
    plt.ylabel("$\\theta_2$")
    plt.xticks([i*jnp.pi for i in range(5)], [f"${i}\pi$" for i in range(5)]) 
    plt.yticks([i*jnp.pi for i in range(5)], [f"${i}\pi$" for i in range(5)]) 
    plt.scatter(xyz[1], xyz[2], c="red", zorder=10)
    plt.grid()
    
    
plot(T1, T2, U1, U2, U3)
plot(T1, T2, D1, D2, D3)
plot(T1, T2, B1, B2, B3)
plot(T1, T2, C1, C2, C3)

# %%
def plt_slice(U, i):
    plt.plot(t1, U[:, i])
    

j = 99
s=1
E1 = (D1 + L*stdev**2)*s
E2 = (D1 + L*stdev**2 - 2*B1)*s# - 2*


for U in [U1, E1, E2, C1]:
    plt_slice(U, j)
    
plt.grid()
plt.xlabel("$\\theta$")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
gauss = lambda t,x: jnp.exp(-x**2/(2*t**2))/jnp.sqrt(2*jnp.pi*t**2)

def two_gauss(t, x, d): 
    return gauss(t, x-d) + gauss(t, x+d)

def n_gauss(t, x, d, n):
    ns = jnp.linspace(-n, n, 2*n+1)
    return jnp.sum(vmap(gauss, (None, 0))(t, x + (2*ns+1)*d))

def thre_gauss(t, x, d):
    return gauss(t, x-d) - gauss(t, x) + gauss(t, x+d)

t = 0.7
d = 0.4
two_gauss_t_d = lambda x: two_gauss(t, x, d)
n_gauss_t_d = lambda x: n_gauss(t, x, d, 10)
thre_gauss_t_d = lambda x: thre_gauss(t, x, d)

x = jnp.linspace(-1, 1, 1000)
plt.plot(x, vmap(thre_gauss_t_d)(x))


plt.figure()
plt.plot(x, vmap(two_gauss_t_d)(x))
plt.plot(x, vmap(n_gauss_t_d)(x))
